# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
     'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
vocab_size=10000

# %%
one_hot_rep=[one_hot(words,vocab_size) for words in sent]
one_hot_rep
# Out:
# [[5708, 6576, 729, 1155],
#  [5708, 6576, 729, 8178],
#  [5708, 5513, 729, 578],
#  [6669, 7384, 1278, 8003, 6209],
#  [6669, 7384, 1278, 8003, 5687],
#  [4547, 5708, 4662, 729, 6207],
#  [5823, 424, 2675, 8003]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
max_len_sent=8

# %%
embedded_docs=pad_sequences(one_hot_rep,padding='pre',maxlen=max_len_sent)
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 5708, 6576,  729, 1155],
#        [   0,    0,    0,    0, 5708, 6576,  729, 8178],
#        [   0,    0,    0,    0, 5708, 5513,  729,  578],
#        [   0,    0,    0, 6669, 7384, 1278, 8003, 6209],
#        [   0,    0,    0, 6669, 7384, 1278, 8003, 5687],
#        [   0,    0,    0, 4547, 5708, 4662,  729, 6207],
#        [   0,    0,    0,    0, 5823,  424, 2675, 8003]], dtype=int32)

# %%
dim=10

# %%
model=Sequential()
model.add(Embedding(vocab_size,dim,input_length=max_len_sent))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# array([[[-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [ 0.02385477,  0.00641609,  0.00695571,  0.04681015,
#           0.02453927,  0.01546171,  0.02718612, -0.00742824,
#           0.02824238, -0.0398178 ],
#         [ 0.00862801,  0.02555728,  0.01412148, -0.0336647 ,
#          -0.02712354, -0.03698008, -0.013894  ,  0.00547128,
#           0.03315153,  0.04130865],
#         [-0.04546579,  0.03319523, -0.02813003, -0.02939708,
#           0.0039549 ,  0.0436953 ,  0.04496783,  0.03970821,
#          -0.03999528, -0.01992679],
#         [-0.02995948, -0.03214431, -0.01637213,  0.0029592 ,
#           0.01243586, -0.02049612, -0.03499096, -0.02610254,
#          -0.02484832,  0.02055856]],
#
#        [[-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [ 0.02385477,  0.00641609,  0.00695571,  0.04681015,
#           0.02453927,  0.01546171,  0.02718612, -0.00742824,
#           0.02824238, -0.0398178 ],
#         [ 0.00862801,  0.02555728,  0.01412148, -0.0336647 ,
#          -0.02712354, -0.03698008, -0.013894  ,  0.00547128,
#           0.03315153,  0.04130865],
#         [-0.04546579,  0.03319523, -0.02813003, -0.02939708,
#           0.0039549 ,  0.0436953 ,  0.04496783,  0.03970821,
#          -0.03999528, -0.01992679],
#         [ 0.04469936,  0.02422955,  0.04535513,  0.0389662 ,
#          -0.04171997, -0.02334015, -0.03983576, -0.02504312,
#          -0.02717791,  0.03102737]],
#
#        [[-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [ 0.02385477,  0.00641609,  0.00695571,  0.04681015,
#           0.02453927,  0.01546171,  0.02718612, -0.00742824,
#           0.02824238, -0.0398178 ],
#         [-0.00555246,  0.0262153 , -0.03050921,  0.02790299,
#           0.00909341, -0.00180062, -0.04867836, -0.04148465,
#           0.03507722,  0.00283139],
#         [-0.04546579,  0.03319523, -0.02813003, -0.02939708,
#           0.0039549 ,  0.0436953 ,  0.04496783,  0.03970821,
#          -0.03999528, -0.01992679],
#         [ 0.02450598,  0.04050524, -0.01186427, -0.04007692,
#           0.00100048,  0.03656192,  0.03287673,  0.0082796 ,
#           0.01670435, -0.00724142]],
#
#        [[-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.03191515, -0.01333981, -0.02294732,  0.01055901,
#           0.02869553,  0.02826763, -0.04201899,  0.0419755 ,
#           0.04161222, -0.04438863],
#         [-0.012446  ,  0.03678508, -0.03251155,  0.00499479,
#          -0.04761541, -0.03231776, -0.00101001, -0.03518761,
#           0.02408883, -0.03934016],
#         [ 0.02163358,  0.04235784, -0.00653174, -0.03461029,
#           0.04223361,  0.02438632,  0.00450084, -0.00728794,
#           0.04334955,  0.01954559],
#         [ 0.03625369, -0.0248587 ,  0.03232128,  0.03303367,
#          -0.02087568, -0.01394271,  0.02451738,  0.00835997,
#           0.00736213, -0.02549075],
#         [ 0.02906225, -0.01095927,  0.03405524, -0.0314137 ,
#          -0.04821298, -0.03237709, -0.00866872, -0.00436598,
#          -0.0038885 , -0.03417419]],
#
#        [[-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.03191515, -0.01333981, -0.02294732,  0.01055901,
#           0.02869553,  0.02826763, -0.04201899,  0.0419755 ,
#           0.04161222, -0.04438863],
#         [-0.012446  ,  0.03678508, -0.03251155,  0.00499479,
#          -0.04761541, -0.03231776, -0.00101001, -0.03518761,
#           0.02408883, -0.03934016],
#         [ 0.02163358,  0.04235784, -0.00653174, -0.03461029,
#           0.04223361,  0.02438632,  0.00450084, -0.00728794,
#           0.04334955,  0.01954559],
#         [ 0.03625369, -0.0248587 ,  0.03232128,  0.03303367,
#          -0.02087568, -0.01394271,  0.02451738,  0.00835997,
#           0.00736213, -0.02549075],
#         [ 0.02369693,  0.04503859, -0.0262856 ,  0.04441838,
#          -0.0070045 , -0.02552073, -0.00997417,  0.01320071,
#           0.02554223, -0.03464059]],
#
#        [[-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.02079706, -0.04279619,  0.00408142,  0.02795044,
#           0.01461479, -0.02394431, -0.03372566,  0.04505813,
#           0.01747378, -0.01382948],
#         [ 0.02385477,  0.00641609,  0.00695571,  0.04681015,
#           0.02453927,  0.01546171,  0.02718612, -0.00742824,
#           0.02824238, -0.0398178 ],
#         [ 0.01563704, -0.01907469,  0.01549139, -0.00909643,
#           0.03508801,  0.01933415, -0.01942537,  0.03633443,
#           0.02639228,  0.04031874],
#         [-0.04546579,  0.03319523, -0.02813003, -0.02939708,
#           0.0039549 ,  0.0436953 ,  0.04496783,  0.03970821,
#          -0.03999528, -0.01992679],
#         [-0.01140426,  0.02916298, -0.04526269, -0.00180177,
#           0.04086859, -0.00466704, -0.0459169 ,  0.00576104,
#          -0.00046871,  0.00370922]],
#
#        [[-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [-0.00473712,  0.02491811,  0.00682091,  0.04287691,
#          -0.03152318, -0.02220741, -0.02538813,  0.03471472,
#          -0.0395781 , -0.01220455],
#         [ 0.0394084 , -0.02347395,  0.01620534, -0.02879691,
#          -0.01070416, -0.04838258, -0.03484404,  0.04178221,
#          -0.03535185,  0.01518276],
#         [ 0.02961231, -0.04995219, -0.04758883,  0.04486603,
#           0.03138527, -0.02019861,  0.01603236, -0.04286175,
#           0.02287154,  0.04485384],
#         [-0.02291348, -0.01606309,  0.01155356, -0.00201149,
#           0.01178543, -0.03808869,  0.00908216,  0.03127019,
#          -0.04672429, -0.02039655],
#         [ 0.03625369, -0.0248587 ,  0.03232128,  0.03303367,
#          -0.02087568, -0.01394271,  0.02451738,  0.00835997,
#           0.00736213, -0.02549075]]], dtype=float32)
